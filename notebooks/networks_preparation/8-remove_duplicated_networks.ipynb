# %%
import numpy as np
import pandas as pd
import os
pd.set_option('display.max_colwidth', None)

# %%
networks_metadata_path = "../../data/networks/networks_metadata.csv"
networks_dir = "../../data/networks/all/"

# %%
networks_metadata = pd.read_csv(networks_metadata_path)
networks_metadata = networks_metadata.rename(columns={"duplicated_network": "mangal_duplicated_network"})

# %% [markdown]
# # report allegendly duplicated networks from mangal based on the data url

# %%
debug = networks_metadata.loc[(networks_metadata.mangal_duplicated_network == True) & (networks_metadata.data_url.str.contains("interactionweb", na=False)) | (networks_metadata.data_url.str.contains("web-of-life", na=False))][["processed_path", "Longitude", "Latitude", "data_url", "num_plants", "num_pollinators"]].sort_values(["num_plants", "num_pollinators"]).drop_duplicates()
debug
# Out:
#                                          processed_path  Longitude   Latitude  \
# 785               ../../data/networks/all/binary/65.csv   124.8640  -2.160885
# 773               ../../data/networks/all/binary/53.csv   124.7780   1.787000
# 772               ../../data/networks/all/binary/52.csv   124.7040   1.616000
# 783               ../../data/networks/all/binary/63.csv   124.7350   1.608000
# 784               ../../data/networks/all/binary/64.csv   124.7930   1.767000
# ...                                                 ...        ...        ...
# 790               ../../data/networks/all/binary/70.csv   -84.8000   9.298777
# 351   ../../data/networks/all/binarized_weighted/351...   -48.4069 -23.489215
# 1252           ../../data/networks/all/weighted/351.csv   -48.4069 -23.489215
# 290   ../../data/networks/all/binarized_weighted/290...   -89.8818  38.029652
# 1191           ../../data/networks/all/weighted/290.csv   -89.8818  38.029652
#
#                                                data_url  num_plants  \
# 785   https://www.nceas.ucsb.edu/interactionweb/data...           2
# 773   https://www.nceas.ucsb.edu/interactionweb/data...           2
# 772   https://www.nceas.ucsb.edu/interactionweb/data...           3
# 783   https://www.nceas.ucsb.edu/interactionweb/data...           3
# 784   https://www.nceas.ucsb.edu/interactionweb/data...           3
# ...                                                 ...         ...
# 790            http://www.web-of-life.es/map.php?type=5         169
# 351            http://www.web-of-life.es/map.php?type=5         198
# 1252           http://www.web-of-life.es/map.php?type=5         198
# 290   https://www.nceas.ucsb.edu/interactionweb/html...         366
# 1191  https://www.nceas.ucsb.edu/interactionweb/html...         366
#
#       num_pollinators
# 785                 3
# 773                 4
# 772                 2
# 783                 3
# 784                 4
# ...               ...
# 790                40
# 351                60
# 1252               60
# 290               963
# 1191              963
#
# [172 rows x 6 columns]

# %% [markdown]
# # detect duplications by first selecting suspects of duplicated networks based on networl size and then directly checking if the networks are indentical within each group of suspects

# %%
def is_equal_net(net1, net2):
    same_plants = set(net1.Plant.str.lower()) == set(net2.Plant.str.lower())
    same_pollinators = set([s.lower() for s in net1.columns if s != "Plant"]) == set([s.lower() for s in net2.columns if s != "Plant"])
    try:
        same_inter = np.all(net1.set_index("Plant").to_numpy() == net2.set_index("Plant"))
    except:
        same_inter = False
    return same_plants & same_pollinators & same_inter
    
    
def get_duplicated_clusters(network_paths):
    path_to_net = {path:pd.read_csv(path) for path in network_paths}
    for p in path_to_net:
        if "Unnamed: 0" in path_to_net[p]:
            path_to_net[p] = path_to_net[p].drop(["Unnamed: 0"], axis=1)
    dups = []
    for i in range(len(network_paths)):
        for j in range(i+1, len(network_paths)):
            if is_equal_net(path_to_net[network_paths[i]], path_to_net[network_paths[j]]):
                dups.append((network_paths[i], network_paths[j]))
    return dups
                


debug = networks_metadata.groupby(["network_type", "num_plants", "num_pollinators"])[["network_index", "path", "processed_path"]].agg({"network_index": lambda n: len(n),
                                                                                                                                                         "path": lambda n: list(n),
                                                                                                                                                         "processed_path": lambda n: list(n)}).reset_index()
debug["from_oik07303"] = debug.path.astype(str).str.contains("oik.07303", na=False)
debug["duplicated_networks"] = debug.processed_path.apply(get_duplicated_clusters)

# %%
debug.loc[debug.duplicated_networks.astype(str) != "[]"]
paths_to_remove = debug.loc[debug.duplicated_networks.astype(str) != "[]"].path.apply(lambda x: x[1:]).tolist()
paths_to_remove = [item for sublist in paths_to_remove for item in sublist]
paths_to_remove
# Out:
# ['../../data/networks//literature/weighted/1_Aigrettes_processed.csv',
#  '../../data/networks//mangal/weighted/934.csv',
#  '../../data/networks//web_of_life/weighted/M_PL_011.csv',
#  '../../data/networks//literature/binary/10.1055_s-0037-1602098_processed.csv',
#  '../../data/networks//literature/binary/2_processed.csv',
#  '../../data/networks//literature/weighted/1_Aigrettes_processed.csv',
#  '../../data/networks//mangal/weighted/934.csv',
#  '../../data/networks//web_of_life/weighted/M_PL_011.csv']

# %%
networks_metadata = networks_metadata.loc[~networks_metadata.path.isin(paths_to_remove)]

# %%
print(f"# remaining networks per type: ")
networks_metadata.groupby("network_type")["network_index"].count()
# Out:
# # remaining networks per type:
# network_type
# binarized_weighted    716
# binary                179
# weighted              716
# Name: network_index, dtype: int64

# %%
print(f"# remaining unique networks of all original types = {networks_metadata.loc[networks_metadata.network_type != 'binarized_weighted'].shape[0]:,}")
# Out:
# # remaining unique networks of all original types = 895

# %%
networks_metadata.to_csv(networks_metadata_path, index=False)

# %% [markdown]
# # less duplicates were detected compared to the ones reported as duplicates from mangal, so allegedly duplicated from mangal will be checked manuall

# %%
mangal_dups = networks_metadata.loc[(networks_metadata.mangal_duplicated_network == True) & (networks_metadata.data_url.str.contains("web-of-life", na=False)) & (networks_metadata.network_type == "weighted")][["processed_path", "EcoRegion_name", "num_plants", "num_pollinators"]].sort_values(["num_plants", "num_pollinators"]).drop_duplicates()
mangal_dups.iloc[:30]
# Out:
#                                 processed_path                EcoRegion_name  \
# 1174  ../../data/networks/all/weighted/273.csv      seychelles moist forests
# 1345  ../../data/networks/all/weighted/444.csv      seychelles moist forests
# 1357  ../../data/networks/all/weighted/456.csv      seychelles moist forests
# 1376  ../../data/networks/all/weighted/475.csv      seychelles moist forests
# 1295  ../../data/networks/all/weighted/394.csv      seychelles moist forests
# 1377  ../../data/networks/all/weighted/476.csv      seychelles moist forests
# 1202  ../../data/networks/all/weighted/301.csv      seychelles moist forests
# 1337  ../../data/networks/all/weighted/436.csv      seychelles moist forests
# 1350  ../../data/networks/all/weighted/449.csv      seychelles moist forests
# 1383  ../../data/networks/all/weighted/482.csv      seychelles moist forests
# 1338  ../../data/networks/all/weighted/437.csv      seychelles moist forests
# 1381  ../../data/networks/all/weighted/480.csv             mascarene forests
# 1318  ../../data/networks/all/weighted/417.csv      seychelles moist forests
# 1297  ../../data/networks/all/weighted/396.csv      seychelles moist forests
# 1309  ../../data/networks/all/weighted/408.csv      seychelles moist forests
# 1329  ../../data/networks/all/weighted/428.csv  northeastern coastal forests
# 1150  ../../data/networks/all/weighted/249.csv             mascarene forests
# 1279  ../../data/networks/all/weighted/378.csv      seychelles moist forests
# 1151  ../../data/networks/all/weighted/250.csv      seychelles moist forests
# 1272  ../../data/networks/all/weighted/371.csv      seychelles moist forests
# 1148  ../../data/networks/all/weighted/247.csv      seychelles moist forests
# 1200  ../../data/networks/all/weighted/299.csv      seychelles moist forests
# 1205  ../../data/networks/all/weighted/304.csv      seychelles moist forests
# 1104  ../../data/networks/all/weighted/203.csv      seychelles moist forests
# 1253  ../../data/networks/all/weighted/352.csv      seychelles moist forests
# 1214  ../../data/networks/all/weighted/313.csv      seychelles moist forests
# 1277  ../../data/networks/all/weighted/376.csv      seychelles moist forests
# 1285  ../../data/networks/all/weighted/384.csv      seychelles moist forests
# 1229  ../../data/networks/all/weighted/328.csv      seychelles moist forests
# 1231  ../../data/networks/all/weighted/330.csv      seychelles moist forests
#
#       num_plants  num_pollinators
# 1174           4                9
# 1345           5               12
# 1357           5               14
# 1376           5               17
# 1295           5               19
# 1377           6               10
# 1202           6               11
# 1337           6               11
# 1350           6               12
# 1383           6               14
# 1338           6               18
# 1381           6               22
# 1318           7               12
# 1297           7               13
# 1309           7               19
# 1329           7               21
# 1150           7               31
# 1279           8               18
# 1151           8               19
# 1272           8               19
# 1148           9               13
# 1200           9               14
# 1205           9               16
# 1104           9               23
# 1253           9               26
# 1214          10               11
# 1277          10               18
# 1285          10               26
# 1229          11               14
# 1231          11               18

# %%
wof_nets = networks_metadata.loc[(networks_metadata.source == "web_of_life") & (networks_metadata.network_type == "weighted")][["processed_path", "EcoRegion_name", "num_plants", "num_pollinators"]].sort_values(["num_plants", "num_pollinators"]).drop_duplicates()
wof_nets.iloc[:30]
# Out:
#                                 processed_path  \
# 1400  ../../data/networks/all/weighted/499.csv
# 1426  ../../data/networks/all/weighted/525.csv
# 1412  ../../data/networks/all/weighted/511.csv
# 1418  ../../data/networks/all/weighted/517.csv
# 1416  ../../data/networks/all/weighted/515.csv
# 1393  ../../data/networks/all/weighted/492.csv
# 1423  ../../data/networks/all/weighted/522.csv
# 1390  ../../data/networks/all/weighted/489.csv
# 1394  ../../data/networks/all/weighted/493.csv
# 1395  ../../data/networks/all/weighted/494.csv
# 1422  ../../data/networks/all/weighted/521.csv
# 1403  ../../data/networks/all/weighted/502.csv
# 1399  ../../data/networks/all/weighted/498.csv
# 1392  ../../data/networks/all/weighted/491.csv
# 1410  ../../data/networks/all/weighted/509.csv
# 1413  ../../data/networks/all/weighted/512.csv
# 1419  ../../data/networks/all/weighted/518.csv
# 1398  ../../data/networks/all/weighted/497.csv
# 1409  ../../data/networks/all/weighted/508.csv
# 1405  ../../data/networks/all/weighted/504.csv
# 1415  ../../data/networks/all/weighted/514.csv
# 1435  ../../data/networks/all/weighted/534.csv
# 1428  ../../data/networks/all/weighted/527.csv
# 1404  ../../data/networks/all/weighted/503.csv
# 1396  ../../data/networks/all/weighted/495.csv
# 1421  ../../data/networks/all/weighted/520.csv
# 1425  ../../data/networks/all/weighted/524.csv
# 1436  ../../data/networks/all/weighted/535.csv
# 1424  ../../data/networks/all/weighted/523.csv
# 1430  ../../data/networks/all/weighted/529.csv
#
#                                                         EcoRegion_name  \
# 1400                              central forest-grasslands transition
# 1426                                              baltic mixed forests
# 1412                                    azores temperate mixed forests
# 1418                                              baltic mixed forests
# 1416                          canary islands dry woodlands and forests
# 1393                                galápagos islands scrubland mosaic
# 1423                                                 mascarene forests
# 1390                          canary islands dry woodlands and forests
# 1394                                kalaallit nunaat low arctic tundra
# 1395                                north atlantic moist mixed forests
# 1422                          canary islands dry woodlands and forests
# 1403                                                      humid pampas
# 1399                                   south island montane grasslands
# 1392                                            atlantic mixed forests
# 1410                                                high arctic tundra
# 1413                                            southern andean steppe
# 1419                                            southern andean steppe
# 1398                                                      humid pampas
# 1409                  scandinavian montane birch forest and grasslands
# 1405                                                      humid pampas
# 1415                                       valdivian temperate forests
# 1435  southwest iberian mediterranean sclerophyllous and mixed forests
# 1428                                                      humid pampas
# 1404                                                            llanos
# 1396                                              baltic mixed forests
# 1421                          canary islands dry woodlands and forests
# 1425                                                high arctic tundra
# 1436                                            atlantic mixed forests
# 1424                               kalaallit nunaat high arctic tundra
# 1430                                                      humid pampas
#
#       num_plants  num_pollinators
# 1400           7               33
# 1426           8               42
# 1412          10               12
# 1418          10               40
# 1416          11               38
# 1393          12                6
# 1423          14               13
# 1390          14               35
# 1394          15               39
# 1395          16               44
# 1422          17               51
# 1403          17               67
# 1399          18               60
# 1392          19              186
# 1410          20               91
# 1413          21               45
# 1419          23               72
# 1398          24               58
# 1409          24              118
# 1405          25               69
# 1415          26              128
# 1435          26              179
# 1428          28               48
# 1404          28               53
# 1396          28               82
# 1421          29               55
# 1425          29               81
# 1436          30              236
# 1424          31               76
# 1430          33               61
